# %% [markdown]
# ### Wordnet Datset

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import json

# %%
wordnet_train_df = pd.read_json('./datasets/WN18RR/wordnet_train.json')
wordnet_train_df = wordnet_train_df.rename(columns={"ID": "original-entity", "term": "entity", "type": "label"})
print("All classes")
print(wordnet_train_df["label"].unique())
# Out:
# All classes
# ['noun' 'verb' 'adjective' 'adverb']

# %%
wordnet_train_df
# Out:
#                original-entity            entity label  \
# 0           __land_reform_NN_1       land reform  noun
# 1                 __cover_VB_1             cover  verb
# 2             __phytology_NN_1         phytology  noun
# 3                 __kamet_NN_1             kamet  noun
# 4              __question_NN_1          question  noun
# ...                        ...               ...   ...
# 40554     __silver_salmon_NN_1     silver salmon  noun
# 40555    __predictability_NN_1    predictability  noun
# 40556          __achillea_NN_1          achillea  noun
# 40557  __private_property_NN_1  private property  noun
# 40558       __dwarf_elder_NN_2       dwarf elder  noun
#
#                                      sentence
# 0
# 1          cover her face with a handkerchief
# 2
# 3
# 4      there was a question about my training
# ...                                       ...
# 40554
# 40555
# 40556
# 40557
# 40558
#
# [40559 rows x 4 columns]

# %%
train, test = train_test_split(wordnet_train_df, train_size=0.9, random_state=42)

# %%
#print(train.info(memory_usage='deep'))
#print(test.sample)

# %%
train = train.to_dict(orient='records')
test = test.to_dict(orient='records')

data = {
    "train": train,
    "test": test
}

#print(data)
json_data = json.dumps(data, indent=4)

# %%
with open('./datasets/WN18RR/wn18rr_entities.json', 'w') as file:
    file.write(json_data)

# %% [markdown]
# ### Geonames Dataset

# %%
{
    "index": 0,
    "name": "Roc Meler",
    "asciname": "Roc Meler",
    "country_code": "AD",
    "country_name": "Andorra",
    "level1": "T",
    "level2": "PK",
    "type-label": "T.PK",
    "type-name": "peak",
    "status": "train"
},

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import json
from tqdm.notebook import tqdm_notebook

# %%
tqdm_notebook.pandas()

# %%
allCoutries = pd.read_csv('./datasets/Geonames/processed-3/allCountries.csv')
country_mapper = pd.read_csv('./assets/CountryCodes/country_codes.csv')
feature_mapper = pd.read_csv('./datasets/Geonames/processed-3/featureCodes_en.csv')

# %%
feature_mapper
# Out:
#     feature-code                                             name  \
# 0         A.ADM1              first-order administrative division
# 1        A.ADM1H   historical first-order administrative division
# 2         A.ADM2             second-order administrative division
# 3        A.ADM2H  historical second-order administrative division
# 4         A.ADM3              third-order administrative division
# ..           ...                                              ...
# 675       V.SCRB                                        scrubland
# 676       V.TREE                                          tree(s)
# 677       V.TUND                                           tundra
# 678        V.VIN                                         vineyard
# 679       V.VINS                                        vineyards
#
#                                            description
# 0    a primary administrative division of a country...
# 1         a former first-order administrative division
# 2    a subdivision of a first-order administrative ...
# 3        a former second-order administrative division
# 4    a subdivision of a second-order administrative...
# ..                                                 ...
# 675  an area of low trees, bushes, and shrubs stunt...
# 676              a conspicuous tree used as a landmark
# 677  a marshy, treeless, high latitude plain, domin...
# 678                           a planting of grapevines
# 679                            plantings of grapevines
#
# [680 rows x 3 columns]

# %%
allCoutries
# Out:
#                                  name                     asciiname  \
# 0                           Roc Meler                     Roc Meler
# 1                Pic de les Abelletes          Pic de les Abelletes
# 2             Estany de les Abelletes       Estany de les Abelletes
# 3        Port Vieux de la Coume d’Ose  Port Vieux de la Coume d'Ose
# 4                Port de la Cabanette          Port de la Cabanette
# ...                               ...                           ...
# 9001159                Hebi Seamounts                Hebi Seamounts
# 9001160                Okkonen Canyon                Okkonen Canyon
# 9001161                      G5 Sahel                      G5 Sahel
# 9001162                      Long Bay                      Long Bay
# 9001163                Kadavu Passage                Kadavu Passage
#
#         country-code level-1 level-2
# 0                 AD       T      PK
# 1                 AD       T      PK
# 2                 AD       H      LK
# 3                 AD       T    PASS
# 4                 AD       T    PASS
# ...              ...     ...     ...
# 9001159          NaN       U    SMSU
# 9001160          NaN       U    CNYU
# 9001161          NaN       L     RGN
# 9001162          NaN       H     BAY
# 9001163          NaN       H    STRT
#
# [9001164 rows x 5 columns]

# %%
train_df = pd.read_json('./datasets/Geonames/geonames_train.json')
train_df = train_df.rename(columns={"term": "name", "type": "type-name"})

# %%
train_df
# Out:
#               ID                     name  \
# 0              0       Pic de Font Blanca
# 1              1                 Roc Mele
# 2              2     Pic des Langounelles
# 3              3     Pic de les Abelletes
# 4              4  Estany de les Abelletes
# ...          ...                      ...
# 8078860  8781370          Yuqing Seamount
# 8078861  8781371    Zelia Gattai Seamount
# 8078862  8781372            Zhenghe Ridge
# 8078863  8781373          Akkadian Empire
# 8078864  8781374     Massif de Perdiguere
#
#                                               type-name
# 0                                                  peak
# 1                                              mountain
# 2                                                  peak
# 3                                                  peak
# 4                                                  lake
# ...                                                 ...
# 8078860                                        seamount
# 8078861                                        seamount
# 8078862                                           ridge
# 8078863  historical first-order administrative division
# 8078864                                       mountains
#
# [8078865 rows x 3 columns]

# %%
agg_func = {
    'country-code': 'first',
    'level-1': 'first',
    'level-2': 'first'
}

allCoutries_agg = allCoutries.groupby('name').agg(agg_func).reset_index()

merged_df = pd.merge(train_df, allCoutries_agg, how='left', left_on='name', right_on='name')

merged_df['combined'] = merged_df['level-1'].astype(str) + '.' + merged_df['level-2'].astype(str)
merged_df = merged_df.fillna({"country-code": "not identified country"})

# %%
merged_df
# Out:
#               ID                     name  \
# 0              0       Pic de Font Blanca
# 1              1                 Roc Mele
# 2              2     Pic des Langounelles
# 3              3     Pic de les Abelletes
# 4              4  Estany de les Abelletes
# ...          ...                      ...
# 8078860  8781370          Yuqing Seamount
# 8078861  8781371    Zelia Gattai Seamount
# 8078862  8781372            Zhenghe Ridge
# 8078863  8781373          Akkadian Empire
# 8078864  8781374     Massif de Perdiguere
#
#                                               type-name  \
# 0                                                  peak
# 1                                              mountain
# 2                                                  peak
# 3                                                  peak
# 4                                                  lake
# ...                                                 ...
# 8078860                                        seamount
# 8078861                                        seamount
# 8078862                                           ridge
# 8078863  historical first-order administrative division
# 8078864                                       mountains
#
#                    country-code level-1 level-2 combined
# 0                            FR       T      PK     T.PK
# 1        not identified country     NaN     NaN  nan.nan
# 2                            FR       T      PK     T.PK
# 3                            AD       T      PK     T.PK
# 4                            AD       H      LK     H.LK
# ...                         ...     ...     ...      ...
# 8078860  not identified country       U     SMU    U.SMU
# 8078861  not identified country     NaN     NaN  nan.nan
# 8078862  not identified country       U    RDGU   U.RDGU
# 8078863  not identified country       A   ADM1H  A.ADM1H
# 8078864  not identified country     NaN     NaN  nan.nan
#
# [8078865 rows x 7 columns]

# %%
na_df = merged_df[merged_df.isna().any(axis=1)]
merged_df = merged_df.dropna()

# %%
na_df = na_df.drop(columns=['level-1', 'level-2', 'combined'])

# %%
na_df
# Out:
#               ID                          name  type-name  \
# 1              1                      Roc Mele   mountain
# 5              5  Port Vieux de la Coume d'Ose       pass
# 23            26              Basers de Vicenc   cliff(s)
# 31            35                     Sola Vell   slope(s)
# 53            59       Cami de la Vall del Riu      trail
# ...          ...                           ...        ...
# 8078827  8781334               Putoto Seamount   seamount
# 8078834  8781342          Sao Francisco Canyon     canyon
# 8078850  8781359                   Uruti Basin      basin
# 8078861  8781371         Zelia Gattai Seamount   seamount
# 8078864  8781374          Massif de Perdiguere  mountains
#
#                    country-code
# 1        not identified country
# 5        not identified country
# 23       not identified country
# 31       not identified country
# 53       not identified country
# ...                         ...
# 8078827  not identified country
# 8078834  not identified country
# 8078850  not identified country
# 8078861  not identified country
# 8078864  not identified country
#
# [1699956 rows x 4 columns]

# %%
agg_func = {
    'feature-code': 'first',
}

feature_mapper_agg = feature_mapper.groupby('name').agg(agg_func).reset_index()
feature_mapper_agg
# Out:
#                        name feature-code
# 0    State Exam Prep Centre       S.SECP
# 1        abandoned airfield       S.AIRQ
# 2            abandoned camp       S.CMPQ
# 3           abandoned canal       H.CNLQ
# 4         abandoned factory       S.MFGQ
# ..                      ...          ...
# 659        wildlife reserve       L.RESW
# 660                windmill      S.MLWND
# 661                   wreck       S.WRCK
# 662                    zone         A.ZN
# 663                     zoo        S.ZOO
#
# [664 rows x 2 columns]

# %%
na_df = na_df.rename(columns={"name": "label"})

# %%
na_df = pd.merge(na_df, feature_mapper_agg, how='left', left_on='type-name', right_on='name')

# %%
na_df
# Out:
#               ID                         label  type-name  \
# 0              1                      Roc Mele   mountain
# 1              5  Port Vieux de la Coume d'Ose       pass
# 2             26              Basers de Vicenc   cliff(s)
# 3             35                     Sola Vell   slope(s)
# 4             59       Cami de la Vall del Riu      trail
# ...          ...                           ...        ...
# 1699951  8781334               Putoto Seamount   seamount
# 1699952  8781342          Sao Francisco Canyon     canyon
# 1699953  8781359                   Uruti Basin      basin
# 1699954  8781371         Zelia Gattai Seamount   seamount
# 1699955  8781374          Massif de Perdiguere  mountains
#
#                    country-code       name feature-code
# 0        not identified country   mountain         T.MT
# 1        not identified country       pass       T.PASS
# 2        not identified country   cliff(s)        T.CLF
# 3        not identified country   slope(s)        T.SLP
# 4        not identified country      trail        R.TRL
# ...                         ...        ...          ...
# 1699951  not identified country   seamount        U.SMU
# 1699952  not identified country     canyon       T.CNYN
# 1699953  not identified country      basin       U.BSNU
# 1699954  not identified country   seamount        U.SMU
# 1699955  not identified country  mountains        T.MTS
#
# [1699956 rows x 6 columns]

# %%
na_df["level-1"], na_df["level-2"] = na_df.progress_apply(lambda x: x["feature-code"].split(".")[0], axis = 1), na_df.progress_apply(lambda x: x["feature-code"].split(".")[1], axis = 1)
na_df['combined'] = na_df['level-1'].astype(str) + '.' + na_df['level-2'].astype(str)
# Out:
#   0%|          | 0/1699956 [00:00<?, ?it/s]
#   0%|          | 0/1699956 [00:00<?, ?it/s]

# %%
na_df
# Out:
#               ID                         label  type-name  \
# 0              1                      Roc Mele   mountain
# 1              5  Port Vieux de la Coume d'Ose       pass
# 2             26              Basers de Vicenc   cliff(s)
# 3             35                     Sola Vell   slope(s)
# 4             59       Cami de la Vall del Riu      trail
# ...          ...                           ...        ...
# 1699951  8781334               Putoto Seamount   seamount
# 1699952  8781342          Sao Francisco Canyon     canyon
# 1699953  8781359                   Uruti Basin      basin
# 1699954  8781371         Zelia Gattai Seamount   seamount
# 1699955  8781374          Massif de Perdiguere  mountains
#
#                    country-code       name feature-code level1 level2
# 0        not identified country   mountain         T.MT      T     MT
# 1        not identified country       pass       T.PASS      T   PASS
# 2        not identified country   cliff(s)        T.CLF      T    CLF
# 3        not identified country   slope(s)        T.SLP      T    SLP
# 4        not identified country      trail        R.TRL      R    TRL
# ...                         ...        ...          ...    ...    ...
# 1699951  not identified country   seamount        U.SMU      U    SMU
# 1699952  not identified country     canyon       T.CNYN      T   CNYN
# 1699953  not identified country      basin       U.BSNU      U   BSNU
# 1699954  not identified country   seamount        U.SMU      U    SMU
# 1699955  not identified country  mountains        T.MTS      T    MTS
#
# [1699956 rows x 8 columns]

# %%
merged_df = pd.concat([merged_df, na_df])

# %%
merged_df
# Out:
#               ID                     name  type-name            country-code  \
# 0              0       Pic de Font Blanca       peak                      FR
# 2              2     Pic des Langounelles       peak                      FR
# 3              3     Pic de les Abelletes       peak                      AD
# 4              4  Estany de les Abelletes       lake                      AD
# 6              6     Port de la Cabanette       pass                      AD
# ...          ...                      ...        ...                     ...
# 1699951  8781334                 seamount   seamount  not identified country
# 1699952  8781342                   canyon     canyon  not identified country
# 1699953  8781359                    basin      basin  not identified country
# 1699954  8781371                 seamount   seamount  not identified country
# 1699955  8781374                mountains  mountains  not identified country
#
#         level-1 level-2 combined                  label feature-code level1  \
# 0             T      PK     T.PK                    NaN          NaN    NaN
# 2             T      PK     T.PK                    NaN          NaN    NaN
# 3             T      PK     T.PK                    NaN          NaN    NaN
# 4             H      LK     H.LK                    NaN          NaN    NaN
# 6             T    PASS   T.PASS                    NaN          NaN    NaN
# ...         ...     ...      ...                    ...          ...    ...
# 1699951     NaN     NaN      NaN        Putoto Seamount        U.SMU      U
# 1699952     NaN     NaN      NaN   Sao Francisco Canyon       T.CNYN      T
# 1699953     NaN     NaN      NaN            Uruti Basin       U.BSNU      U
# 1699954     NaN     NaN      NaN  Zelia Gattai Seamount        U.SMU      U
# 1699955     NaN     NaN      NaN   Massif de Perdiguere        T.MTS      T
#
#         level2
# 0          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 6          NaN
# ...        ...
# 1699951    SMU
# 1699952   CNYN
# 1699953   BSNU
# 1699954    SMU
# 1699955    MTS
#
# [8078865 rows x 11 columns]

# %%
train, test = train_test_split(train_df, train_size=0.99, random_state=42)

# %%
train

# %%
test

# %%
train = train.to_dict(orient='records')
test = test.to_dict(orient='records')

data = {
    "train": train,
    "test": test
}

#print(data)
json_data = json.dumps(data, indent=4)

# %%
with open('./datasets/Geonames/geonames_entities.json', 'w') as file:
    file.write(json_data)

# %%
train_df = pd.read_json('./datasets/Geonames/geonames_entities.json')
train_df.head()
# Out:
#    ID                     term      type
# 0   0       Pic de Font Blanca      peak
# 1   1                 Roc Mele  mountain
# 2   2     Pic des Langounelles      peak
# 3   3     Pic de les Abelletes      peak
# 4   4  Estany de les Abelletes      lake

# %%
print(len(train_df['type'].unique()))
# Out:
# 660

# %%
print(len(train_df['type'].unique()))
print(train_df.count())
# Out:
# 660
# ID      8078865
# term    8078781
# type    8078865
# dtype: int64

# %% [markdown]
# ### Medcin

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import json

# %%
f = open('./datasets-old/UMLS/label_mapper.json')
label_mapper = json.load(f)

# %%
train_df = pd.read_json('./datasets/UMLS/medcin_train.json')
train_df.head()
# Out:
#            ID                            term  \
# 0  C0000294-0              mesna (medication)
# 1  C0000473-1  aminobenzoic acid (medication)
# 2  C0000477-2    CNS stimulants dalfampridine
# 3  C0000618-4   6-mercaptopurine (medication)
# 4  C0000727-5       acute abdomen (diagnosis)
#
#                                                 type
# 0        [organic chemical, pharmacologic substance]
# 1  [organic chemical, pharmacologic substance, vi...
# 2        [organic chemical, pharmacologic substance]
# 3  [nucleic acid, nucleoside, or nucleotide, phar...
# 4                                  [sign or symptom]

# %%
def get_label_str(row):
    labels = []
    for label in label_mapper:
        for data in row["type"]:
            # print(data)
            mapper =  [x.lower() for x in label_mapper[label]]
            if data.lower() in mapper:
        # print(label_mapper[label])
                labels.append(label)
    return list(set(labels))

# %%
train_df["label-str"] = train_df.apply(get_label_str, axis = 1)

# %%
train_df
# Out:
#                      ID                                               term  \
# 0            C0000294-0                                 mesna (medication)
# 1            C0000473-1                     aminobenzoic acid (medication)
# 2            C0000477-2                       CNS stimulants dalfampridine
# 3            C0000618-4                      6-mercaptopurine (medication)
# 4            C0000727-5                          acute abdomen (diagnosis)
# ...                 ...                                                ...
# 277023  C5685946-346280              WABC receptive testing standard score
# 277024  C5685947-346281  xenograft implantation into articular surface ...
# 277025  C5685948-346282  x-ray of upper GI tract, including Scout abdom...
# 277026  C5685949-346283  x-ray of upper GI tract, including Scout abdom...
# 277027  C5685951-346285  alteration of chest subcutaneous tissue and fa...
#
#                                                      type  \
# 0             [organic chemical, pharmacologic substance]
# 1       [organic chemical, pharmacologic substance, vi...
# 2             [organic chemical, pharmacologic substance]
# 3       [nucleic acid, nucleoside, or nucleotide, phar...
# 4                                       [sign or symptom]
# ...                                                   ...
# 277023                                          [finding]
# 277024              [therapeutic or preventive procedure]
# 277025                             [diagnostic procedure]
# 277026                             [diagnostic procedure]
# 277027              [therapeutic or preventive procedure]
#
#                                      label-str
# 0                     [A1.4.1.1.1, A1.4.1.2.1]
# 1       [A1.4.1.1.1, A1.4.1.1.3.4, A1.4.1.2.1]
# 2                     [A1.4.1.1.1, A1.4.1.2.1]
# 3                   [A1.4.1.1.1, A1.4.1.2.1.5]
# 4                                     [A2.2.2]
# ...                                        ...
# 277023                                  [A2.2]
# 277024                              [B1.3.1.3]
# 277025                              [B1.3.1.2]
# 277026                              [B1.3.1.2]
# 277027                              [B1.3.1.3]
#
# [277028 rows x 4 columns]

# %%
train_df = train_df.rename(columns={"term": "concept"})

# %%
train_df
# Out:
#                      ID                                            concept  \
# 0            C0000294-0                                 mesna (medication)
# 1            C0000473-1                     aminobenzoic acid (medication)
# 2            C0000477-2                       CNS stimulants dalfampridine
# 3            C0000618-4                      6-mercaptopurine (medication)
# 4            C0000727-5                          acute abdomen (diagnosis)
# ...                 ...                                                ...
# 277023  C5685946-346280              WABC receptive testing standard score
# 277024  C5685947-346281  xenograft implantation into articular surface ...
# 277025  C5685948-346282  x-ray of upper GI tract, including Scout abdom...
# 277026  C5685949-346283  x-ray of upper GI tract, including Scout abdom...
# 277027  C5685951-346285  alteration of chest subcutaneous tissue and fa...
#
#                                                      type  \
# 0             [organic chemical, pharmacologic substance]
# 1       [organic chemical, pharmacologic substance, vi...
# 2             [organic chemical, pharmacologic substance]
# 3       [nucleic acid, nucleoside, or nucleotide, phar...
# 4                                       [sign or symptom]
# ...                                                   ...
# 277023                                          [finding]
# 277024              [therapeutic or preventive procedure]
# 277025                             [diagnostic procedure]
# 277026                             [diagnostic procedure]
# 277027              [therapeutic or preventive procedure]
#
#                                      label-str
# 0                     [A1.4.1.1.1, A1.4.1.2.1]
# 1       [A1.4.1.1.1, A1.4.1.1.3.4, A1.4.1.2.1]
# 2                     [A1.4.1.1.1, A1.4.1.2.1]
# 3                   [A1.4.1.1.1, A1.4.1.2.1.5]
# 4                                     [A2.2.2]
# ...                                        ...
# 277023                                  [A2.2]
# 277024                              [B1.3.1.3]
# 277025                              [B1.3.1.2]
# 277026                              [B1.3.1.2]
# 277027                              [B1.3.1.3]
#
# [277028 rows x 4 columns]

# %%
train, test = train_test_split(train_df, train_size=0.9, random_state=42)

# %%
train["status"] = "train"
test["status"] = "test"

# %%
df_concat = pd.concat([train, test])

# %%
df_concat
# Out:
#                      ID                                            concept  \
# 101192  C2106775-126398     complete retinal detachment (physical finding)
# 102907  C2108916-128503        knee joint pain only with jumping (symptom)
# 40962    C2030211-51205  heat therapy of posterior surface of right elb...
# 61650    C2056385-77052  tenderness on palpation of dorsal aspect of di...
# 57447    C2051083-71822        patch on right antihelix (physical finding)
# ...                 ...                                                ...
# 156984  C2177051-196045  muscle spasm of infraspinatus region of left s...
# 163582  C2185389-204301      long-term: overhead reaching with supervision
# 79487    C2079273-99358                 iris bombe of left eye (diagnosis)
# 191730  C2221120-239617     puncture of finger by knife (physical finding)
# 106315  C2113232-132784  physical therapy precautions limit active assi...
#
#                                          type     label-str status
# 101192                              [finding]        [A2.2]  train
# 102907                      [sign or symptom]      [A2.2.2]  train
# 40962   [therapeutic or preventive procedure]    [B1.3.1.3]  train
# 61650                               [finding]        [A2.2]  train
# 57447                               [finding]        [A2.2]  train
# ...                                       ...           ...    ...
# 156984                              [finding]        [A2.2]   test
# 163582  [therapeutic or preventive procedure]    [B1.3.1.3]   test
# 79487                   [disease or syndrome]  [B2.2.1.2.1]   test
# 191730                              [finding]        [A2.2]   test
# 106315  [therapeutic or preventive procedure]    [B1.3.1.3]   test
#
# [277028 rows x 5 columns]

# %%
data = df_concat.to_dict(orient='records')
json_data = json.dumps(data, indent=4)

# %%
with open('./datasets/UMLS/medcin_entities.json', 'w') as file:
    file.write(json_data)

# %% [markdown]
# ### NCI

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import json

# %%
f = open('./datasets-old/UMLS/label_mapper.json')
label_mapper = json.load(f)

# %%
train_df = pd.read_json('./datasets/UMLS/nci_train.json')
train_df.head()
# Out:
#            ID                                               term  \
# 0  C0000325-1          1,2-Dihydro-3-methyl-benz(j)aceanthrylene
# 1  C0000598-2  5-(o-Chlorobenzyl)-4,5,6,7-tetrahydrothieno(3,...
# 2  C0000699-3                                 Antibiotic A-23187
# 3  C0000742-4                                             A-MuLV
# 4  C0000768-5                 Congenital Anomaly or Birth Defect
#
#                                                 type
# 0  [organic chemical, hazardous or poisonous subs...
# 1        [organic chemical, pharmacologic substance]
# 2                     [organic chemical, antibiotic]
# 3                                            [virus]
# 4                           [congenital abnormality]

# %%
def get_label_str(row):
    labels = []
    for label in label_mapper:
        for data in row["type"]:
            # print(data)
            mapper =  [x.lower() for x in label_mapper[label]]
            if data.lower() in mapper:
        # print(label_mapper[label])
                labels.append(label)
    return list(set(labels))

# %%
train_df["label-str"] = train_df.apply(get_label_str, axis = 1)

# %%
train_df
# Out:
#                      ID                                               term  \
# 0            C0000294-0                                 mesna (medication)
# 1            C0000473-1                     aminobenzoic acid (medication)
# 2            C0000477-2                       CNS stimulants dalfampridine
# 3            C0000618-4                      6-mercaptopurine (medication)
# 4            C0000727-5                          acute abdomen (diagnosis)
# ...                 ...                                                ...
# 277023  C5685946-346280              WABC receptive testing standard score
# 277024  C5685947-346281  xenograft implantation into articular surface ...
# 277025  C5685948-346282  x-ray of upper GI tract, including Scout abdom...
# 277026  C5685949-346283  x-ray of upper GI tract, including Scout abdom...
# 277027  C5685951-346285  alteration of chest subcutaneous tissue and fa...
#
#                                                      type  \
# 0             [organic chemical, pharmacologic substance]
# 1       [organic chemical, pharmacologic substance, vi...
# 2             [organic chemical, pharmacologic substance]
# 3       [nucleic acid, nucleoside, or nucleotide, phar...
# 4                                       [sign or symptom]
# ...                                                   ...
# 277023                                          [finding]
# 277024              [therapeutic or preventive procedure]
# 277025                             [diagnostic procedure]
# 277026                             [diagnostic procedure]
# 277027              [therapeutic or preventive procedure]
#
#                                      label-str
# 0                     [A1.4.1.1.1, A1.4.1.2.1]
# 1       [A1.4.1.1.1, A1.4.1.1.3.4, A1.4.1.2.1]
# 2                     [A1.4.1.1.1, A1.4.1.2.1]
# 3                   [A1.4.1.1.1, A1.4.1.2.1.5]
# 4                                     [A2.2.2]
# ...                                        ...
# 277023                                  [A2.2]
# 277024                              [B1.3.1.3]
# 277025                              [B1.3.1.2]
# 277026                              [B1.3.1.2]
# 277027                              [B1.3.1.3]
#
# [277028 rows x 4 columns]

# %%
train_df = train_df.rename(columns={"term": "concept"})

# %%
train_df
# Out:
#                     ID                                            concept  \
# 0           C0000325-1          1,2-Dihydro-3-methyl-benz(j)aceanthrylene
# 1           C0000598-2  5-(o-Chlorobenzyl)-4,5,6,7-tetrahydrothieno(3,...
# 2           C0000699-3                                 Antibiotic A-23187
# 3           C0000742-4                                             A-MuLV
# 4           C0000768-5                 Congenital Anomaly or Birth Defect
# ...                ...                                                ...
# 96172  C5671067-120216                                  AR-v7 Measurement
# 96173  C5671068-120217                             Epithelium Attenuation
# 96174  C5671069-120218                      Gene Level Copy Number Scores
# 96175  C5671070-120219                                               RPMA
# 96176  C5671071-120220                         Supernumerary Hemivertebra
#
#                                                     type  \
# 0      [organic chemical, hazardous or poisonous subs...
# 1            [organic chemical, pharmacologic substance]
# 2                         [organic chemical, antibiotic]
# 3                                                [virus]
# 4                               [congenital abnormality]
# ...                                                  ...
# 96172                             [laboratory procedure]
# 96173                                          [finding]
# 96174                             [intellectual product]
# 96175             [molecular biology research technique]
# 96176                           [congenital abnormality]
#
#                         label-str
# 0        [A1.4.1.2.1, A1.4.1.1.5]
# 1        [A1.4.1.2.1, A1.4.1.1.1]
# 2      [A1.4.1.2.1, A1.4.1.1.1.1]
# 3                [A1.1.4, A1.1.2]
# 4                      [A1.2.2.1]
# ...                           ...
# 96172                  [B1.3.1.1]
# 96173                      [A2.2]
# 96174                      [A2.4]
# 96175                  [B1.3.2.1]
# 96176                  [A1.2.2.1]
#
# [96177 rows x 4 columns]

# %%
train, test = train_test_split(train_df, train_size=0.9, random_state=42)

# %%
train["status"] = "train"
test["status"] = "test"

# %%
df_concat = pd.concat([train, test])

# %%
df_concat
# Out:
#                     ID                                            concept  \
# 3627     C0281303-4547                                     CBDCA/CDDP/TAX
# 16408   C1518157-20527                                       Major Groove
# 13955   C1514579-17444                          Proximal Connecting Fiber
# 11931   C1511535-14915                          Cost Effective Management
# 65005   C4331981-81106  Head and Neck Cancer Clinical Regional Lymph N...
# ...                ...                                                ...
# 47325   C3639894-59167           COMM - Seriously Thought of Hurting Self
# 89136  C5447127-111370                                 Time Amount Answer
# 57481   C3899909-71812  2-Methoxy-5-(((2-(2,4,6-trimethoxyphenyl)ethen...
# 51709   C3827852-64653                TDI - Change in Magnitude of Effort
# 40922   C2983865-51153                                        Stirimazole
#
#                                                     type  \
# 3627               [therapeutic or preventive procedure]
# 16408  [nucleic acid, nucleoside, or nucleotide, biol...
# 13955                                   [cell component]
# 11931                         [occupation or discipline]
# 65005                                          [finding]
# ...                                                  ...
# 47325                             [intellectual product]
# 89136                             [intellectual product]
# 57481        [organic chemical, pharmacologic substance]
# 51709                             [intellectual product]
# 40922        [organic chemical, pharmacologic substance]
#
#                         label-str status
# 3627                   [B1.3.1.3]  train
# 16408  [A1.4.1.2.1.5, A1.4.1.1.3]  train
# 13955                  [A1.2.3.4]  train
# 11931                      [A2.6]  train
# 65005                      [A2.2]  train
# ...                           ...    ...
# 47325                      [A2.4]   test
# 89136                      [A2.4]   test
# 57481    [A1.4.1.2.1, A1.4.1.1.1]   test
# 51709                      [A2.4]   test
# 40922    [A1.4.1.2.1, A1.4.1.1.1]   test
#
# [96177 rows x 5 columns]

# %%
data = df_concat.to_dict(orient='records')
json_data = json.dumps(data, indent=4)

# %%
with open('./datasets/UMLS/nci_entities.json', 'w') as file:
    file.write(json_data)

# %% [markdown]
# ### Snomedct

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import json

# %%
f = open('./datasets-old/UMLS/label_mapper.json')
label_mapper = json.load(f)

# %%
train_df = pd.read_json('./datasets/UMLS/snomedct_us_train.json')
train_df.head()
# Out:
#            ID                                  term  \
# 0  C0000167-0            17-Oxosteroids (substance)
# 1  C0000172-1  18-Hydroxycorticosterone (substance)
# 2  C0000714-2                  Temephos (substance)
# 3  C0000726-4  Abdominal structure (body structure)
# 4  C0000729-5       [D]Abdominal cramps (situation)
#
#                                                 type
# 0                        [organic chemical, hormone]
# 1        [organic chemical, pharmacologic substance]
# 2  [organic chemical, hazardous or poisonous subs...
# 3                          [body location or region]
# 4                                  [sign or symptom]

# %%
def get_label_str(row):
    labels = []
    for label in label_mapper:
        for data in row["type"]:
            # print(data)
            mapper =  [x.lower() for x in label_mapper[label]]
            if data.lower() in mapper:
        # print(label_mapper[label])
                labels.append(label)
    return list(set(labels))

# %%
train_df["label-str"] = train_df.apply(get_label_str, axis = 1)

# %%
train_df
# Out:
#                      ID                                               term  \
# 0            C0000167-0                         17-Oxosteroids (substance)
# 1            C0000172-1               18-Hydroxycorticosterone (substance)
# 2            C0000714-2                               Temephos (substance)
# 3            C0000726-4               Abdominal structure (body structure)
# 4            C0000729-5                    [D]Abdominal cramps (situation)
# ...                 ...                                                ...
# 278369  C5699985-347962  Evacuated blood collection tube with silicone-...
# 278370  C5699986-347963  Evacuated blood collection tube with K2EDTA (d...
# 278371  C5699987-347964  Evacuated blood collection tube with heparin s...
# 278372  C5699988-347965                    MAKOplasty of joint (procedure)
# 278373  C5699989-347966               MAKOplasty of knee joint (procedure)
#
#                                                      type  \
# 0                             [organic chemical, hormone]
# 1             [organic chemical, pharmacologic substance]
# 2       [organic chemical, hazardous or poisonous subs...
# 3                               [body location or region]
# 4                                       [sign or symptom]
# ...                                                   ...
# 278369                                   [medical device]
# 278370                                   [medical device]
# 278371                                   [medical device]
# 278372              [therapeutic or preventive procedure]
# 278373              [therapeutic or preventive procedure]
#
#                          label-str
# 0       [A1.4.1.2.1, A1.4.1.1.3.2]
# 1         [A1.4.1.2.1, A1.4.1.1.1]
# 2         [A1.4.1.2.1, A1.4.1.1.5]
# 3                       [A2.1.5.2]
# 4                         [A2.2.2]
# ...                            ...
# 278369                    [A1.3.1]
# 278370                    [A1.3.1]
# 278371                    [A1.3.1]
# 278372                  [B1.3.1.3]
# 278373                  [B1.3.1.3]
#
# [278374 rows x 4 columns]

# %%
train_df = train_df.rename(columns={"term": "concept"})

# %%
train_df
# Out:
#                      ID                                            concept  \
# 0            C0000167-0                         17-Oxosteroids (substance)
# 1            C0000172-1               18-Hydroxycorticosterone (substance)
# 2            C0000714-2                               Temephos (substance)
# 3            C0000726-4               Abdominal structure (body structure)
# 4            C0000729-5                    [D]Abdominal cramps (situation)
# ...                 ...                                                ...
# 278369  C5699985-347962  Evacuated blood collection tube with silicone-...
# 278370  C5699986-347963  Evacuated blood collection tube with K2EDTA (d...
# 278371  C5699987-347964  Evacuated blood collection tube with heparin s...
# 278372  C5699988-347965                    MAKOplasty of joint (procedure)
# 278373  C5699989-347966               MAKOplasty of knee joint (procedure)
#
#                                                      type  \
# 0                             [organic chemical, hormone]
# 1             [organic chemical, pharmacologic substance]
# 2       [organic chemical, hazardous or poisonous subs...
# 3                               [body location or region]
# 4                                       [sign or symptom]
# ...                                                   ...
# 278369                                   [medical device]
# 278370                                   [medical device]
# 278371                                   [medical device]
# 278372              [therapeutic or preventive procedure]
# 278373              [therapeutic or preventive procedure]
#
#                          label-str
# 0       [A1.4.1.2.1, A1.4.1.1.3.2]
# 1         [A1.4.1.2.1, A1.4.1.1.1]
# 2         [A1.4.1.2.1, A1.4.1.1.5]
# 3                       [A2.1.5.2]
# 4                         [A2.2.2]
# ...                            ...
# 278369                    [A1.3.1]
# 278370                    [A1.3.1]
# 278371                    [A1.3.1]
# 278372                  [B1.3.1.3]
# 278373                  [B1.3.1.3]
#
# [278374 rows x 4 columns]

# %%
train, test = train_test_split(train_df, train_size=0.9, random_state=42)

# %%
train["status"] = "train"
test["status"] = "test"

# %%
df_concat = pd.concat([train, test])

# %%
df_concat
# Out:
#                      ID                                            concept  \
# 146825  C0730100-183371  Metatarsophalangeal joint synovium of lesser t...
# 63278    C0395229-79073        Protective suture of eyelid NOS (procedure)
# 153326  C1068497-191504             Chromohalobacter canadensis (organism)
# 100285  C0450885-125356            Spinal acupuncture T10 (body structure)
# 40081    C0313179-50098               Blood group antibody Hut (substance)
# ...                 ...                                                ...
# 254924  C4750618-318577  Otitis externa of right external auditory cana...
# 10671    C0185767-13277  Closed reduction of fracture of alveolar proce...
# 55463    C0341118-69324         Eosinophilic ulcer of esophagus (disorder)
# 81734   C0423042-102284                    Divergence paralysis (disorder)
# 159694  C1269846-199540                           Single teletherapy field
#
#                                                      type  \
# 146825             [body part, organ, or organ component]
# 63278               [therapeutic or preventive procedure]
# 153326                                        [bacterium]
# 100285                          [body location or region]
# 40081   [amino acid, peptide, or protein, immunologic ...
# ...                                                   ...
# 254924                              [disease or syndrome]
# 10671               [therapeutic or preventive procedure]
# 55463                               [disease or syndrome]
# 81734                                   [sign or symptom]
# 159694                              [qualitative concept]
#
#                            label-str status
# 146825                    [A1.2.3.1]  train
# 63278                     [B1.3.1.3]  train
# 153326                      [A1.1.2]  train
# 100285                    [A2.1.5.2]  train
# 40081   [A1.4.1.2.1.7, A1.4.1.1.3.5]  train
# ...                              ...    ...
# 254924                  [B2.2.1.2.1]   test
# 10671                     [B1.3.1.3]   test
# 55463                   [B2.2.1.2.1]   test
# 81734                       [A2.2.2]   test
# 159694                      [A2.1.2]   test
#
# [278374 rows x 5 columns]

# %%
data = df_concat.to_dict(orient='records')
json_data = json.dumps(data, indent=4)

# %%
with open('./datasets/UMLS/snomedct_us_entities.json', 'w') as file:
    file.write(json_data)

# %% [markdown]
# ### Biological

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import json

# %%
train_df = pd.read_json('./datasets/GO/biological_process_train.json')
train_df.head()
# Out:
#    ID                                               term  \
# 0   0                       Splicing factor 3a subunit 2
# 1   1                                         im:7158514
# 2   2  Glycerophosphodiester phosphodiesterase domain...
# 3   3                                         JUMONJI 13
# 4   4                      TLC domain-containing protein
#
#                                                 type
# 0  [positive regulation of gene expression, mRNA ...
# 1                               [biological_process]
# 2  [lipid metabolic process, positive regulation ...
# 3  [regulation of DNA-templated transcription, ne...
# 4  [retina development in camera-type eye, cerami...

# %%
train, test = train_test_split(train_df, train_size=0.9, random_state=42)

# %%
train["status"] = "train"
test["status"] = "test"

# %%
df_concat = pd.concat([train, test])

# %%
df_concat
# Out:
#             ID                                               term  \
# 177019  177019     PITSLRE serine/threonine-protein kinase CDC2L1
# 145952  145952  RL12, ribosomal protein 11 60S large ribosomal...
# 126132  126132                                            EMB2555
# 159038  159038                           GTP-binding protein ryh1
# 43895    43895  olfactory receptor family 2 subfamily Y member 1G
# ...        ...                                                ...
# 185552  185552                                          At3g46020
# 170628  170628        Frizzled/smoothened-like sans CRD protein H
# 52950    52950  gamma-aminobutyric acid (GABA) A receptor, alp...
# 14107    14107                        NT-3 growth factor receptor
# 134778  134778  Mitochondrial genome maintenance protein MGM10...
#
#                                                      type status
# 177019                               [biological_process]  train
# 145952                                      [translation]  train
# 126132                               [biological_process]  train
# 159038  [retrograde vesicle-mediated transport, Golgi ...  train
# 43895   [sensory perception of smell, detection of che...  train
# ...                                                   ...    ...
# 185552  [positive regulation of mRNA splicing, via spl...   test
# 170628                               [biological_process]   test
# 52950   [monoatomic ion transport, chloride transport,...   test
# 14107   [phosphorylation, transmembrane receptor prote...   test
# 134778                    [interstrand cross-link repair]   test
#
# [195775 rows x 4 columns]

# %%
data = df_concat.to_dict(orient='records')
json_data = json.dumps(data, indent=4)

# %%
with open('./datasets/GO/biological_entities.json', 'w') as file:
    file.write(json_data)

# %% [markdown]
# ### Cellular

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import json

# %%
train_df = pd.read_json('./datasets/GO/cellular_component_train.json')
train_df.head()
# Out:
#    ID                                               term  \
# 0   0                       neurofilament medium chain b
# 1   1           Cytochrome c mitochondrial import factor
# 2   2                    LIM domain-containing protein 2
# 3   3              Large ribosomal subunit protein bL32m
# 4   4  Fungal STAND N-terminal Goodbye domain-contain...
#
#                                                 type
# 0                                  [axon, cytoplasm]
# 1                                    [mitochondrion]
# 2  [actin cytoskeleton, cytosol, plasma membrane,...
# 3  [mitochondrion, mitochondrial large ribosomal ...
# 4                               [cellular_component]

# %%
train, test = train_test_split(train_df, train_size=0.9, random_state=42)

# %%
train["status"] = "train"
test["status"] = "test"

# %%
df_concat = pd.concat([train, test])

# %%
df_concat
# Out:
#             ID                                               term  \
# 137635  137635                              BnaC09g41740D protein
# 147198  147198                    tubulin-folding cofactor E-like
# 29637    29637             mediator complex subunit 10 L homeolog
# 109327  109327                                       YALI0D27170p
# 164569  164569  Canis lupus familiaris (dog) U6 spliceosomal R...
# ...        ...                                                ...
# 195343  195343  olfactory receptor family 8 subfamily G member...
# 12142    12142  Zinc finger MYND domain-containing protein 11 ...
# 116244  116244  cyclophilin family peptidyl-prolyl cis-trans i...
# 14194    14194                Transport and Golgi organization 14
# 152615  152615  Sus scrofa (pig) U6 spliceosomal RNA (ENSSSCG0...
#
#                                                      type status
# 137635                                      [nucleoplasm]  train
# 147198                                        [cytoplasm]  train
# 29637                                           [nucleus]  train
# 109327                                          [cytosol]  train
# 164569           [U4/U6 x U5 tri-snRNP complex, U6 snRNP]  train
# ...                                                   ...    ...
# 195343                                  [plasma membrane]   test
# 12142                              [nucleus, nucleoplasm]   test
# 116244                      [cytosol, nucleus, cytoplasm]   test
# 14194   [endoplasmic reticulum membrane, endoplasmic r...   test
# 152615           [U4/U6 x U5 tri-snRNP complex, U6 snRNP]   test
#
# [228460 rows x 4 columns]

# %%
data = df_concat.to_dict(orient='records')
json_data = json.dumps(data, indent=4)

# %%
with open('./datasets/GO/cellular_entities.json', 'w') as file:
    file.write(json_data)

# %% [markdown]
# # Molecular

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import json

# %%
train_df = pd.read_json('./datasets/GO/molecular_function_train.json')
train_df.head()
# Out:
#    ID                                               term  \
# 0   0  Transcription activator of gluconeogenesis ERT1-1
# 1   1  HECT domain containing E3 ubiquitin protein li...
# 2   2                           SET domain containing 1A
# 3   3                         EPH receptor B3 S homeolog
# 4   4    cyclin dependent kinase 5, regulatory subunit 1
#
#                                                 type
# 0  [DNA-binding transcription factor activity, RN...
# 1  [ubiquitin-protein transferase activity, ubiqu...
# 2  [protein binding, methyltransferase activity, ...
# 3  [protein tyrosine kinase activity, protein kin...
# 4  [calcium ion binding, kinase activity, proteas...

# %%
train, test = train_test_split(train_df, train_size=0.9, random_state=42)

# %%
train["status"] = "train"
test["status"] = "test"

# %%
df_concat = pd.concat([train, test])

# %%
df_concat
# Out:
#             ID                                               term  \
# 191611  191611                 sodium leak channel, non-selective
# 110865  110865                                          AT3G05570
# 181293  181293                         RIKEN cDNA 1700023A20 gene
# 183151  183151                                          AT5G28610
# 148678  148678          DSC E3 ubiquitin ligase complex subunit 1
# ...        ...                                                ...
# 147756  147756                                            EMB1827
# 189204  189204                              BnaAnng07540D protein
# 191971  191971                               Tubulin beta-7 chain
# 144880  144880  olfactory receptor family 2 subfamily A member 54
# 31929    31929              Vasodilator stimulated phosphoprotein
#
#                                             type status
# 191611      [monoatomic cation channel activity]  train
# 110865                      [molecular_function]  train
# 181293                      [molecular_function]  train
# 183151                      [molecular_function]  train
# 148678       [ubiquitin protein ligase activity]  train
# ...                                          ...    ...
# 147756                      [molecular_function]   test
# 189204                             [GTP binding]   test
# 191971  [structural constituent of cytoskeleton]   test
# 144880             [olfactory receptor activity]   test
# 31929                       [SH3 domain binding]   test
#
# [196074 rows x 4 columns]

# %%
data = df_concat.to_dict(orient='records')
json_data = json.dumps(data, indent=4)

# %%
with open('./datasets/GO/molecular_entities.json', 'w') as file:
    file.write(json_data)
